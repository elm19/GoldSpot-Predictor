# %%
import numpy as np
import pandas as pd

# %%
callender_data = pd.read_csv('../data/raw-data/economic_calendar_19_24.csv', index_col='Date')
callender_data.head()
# Out:
#               Day   Hour Country                         Event Actual  \
# Date
# 01/01/19  Tuesday  20:45      CN  Caixin Manufacturing PMI DEC   49.7
# 01/04/19   Friday   8:30      US         Non Farm Payrolls DEC   312K
# 01/06/19   Sunday    NaN      CN          US-China Trade Talks    NaN
# 01/07/19   Monday  10:00      CA              Ivey PMI s.a DEC   59.7
# 01/07/19   Monday    NaN      CN          US-China Trade Talks    NaN
#
#          Previous Consensus Forecast
# Date
# 01/01/19     50.2      50.1     50.1
# 01/04/19     176K      177K     165K
# 01/06/19      NaN       NaN      NaN
# 01/07/19     57.2      56.8     56.7
# 01/07/19      NaN       NaN      NaN

# %% [markdown]
# We will focus on daily or 4-hourly charts at most, meaning the exact time of the news is not relevant for now, so it will be removed.
#
# Additionally, the columns `Actual`, `Previous`, `Consensus`, and `Forecast` will be dropped, as we will allow the model to infer their impact on its own(merged data).

# %%
callender_data.drop(['Actual'], axis=1, inplace=True)
callender_data.drop('Previous', axis=1, inplace=True)
callender_data.drop('Forecast', axis=1, inplace=True)
callender_data.drop('Consensus', axis=1, inplace=True)
callender_data.drop('Hour', axis=1, inplace=True)

callender_data.head()
# Out:
#               Day Country                         Event
# Date
# 01/01/19  Tuesday      CN  Caixin Manufacturing PMI DEC
# 01/04/19   Friday      US         Non Farm Payrolls DEC
# 01/06/19   Sunday      CN          US-China Trade Talks
# 01/07/19   Monday      CA              Ivey PMI s.a DEC
# 01/07/19   Monday      CN          US-China Trade Talks

# %% [markdown]
# Next, we will apply one-hot encoding to this dataframe.

# %%
callender_oneHotEncoded= pd.get_dummies(callender_data, columns=['Day','Country', 'Event'], prefix=['Day', 'Country', 'Event'])
callender_oneHotEncoded.sort_index(inplace=True)
callender_oneHotEncoded.head()
# Out:
#           Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# Date
# 01/01/19       False       False         False       False         False
# 01/01/20       False       False         False       False         False
# 01/02/23       False        True         False       False         False
# 01/03/20        True       False         False       False         False
# 01/03/21       False       False         False        True         False
#
#           Day_Tuesday  Day_Wednesday  Country_CA  Country_CN  Country_EA  ...  \
# Date                                                                      ...
# 01/01/19         True          False       False        True       False  ...
# 01/01/20        False           True       False        True       False  ...
# 01/02/23        False          False       False        True       False  ...
# 01/03/20        False          False       False       False       False  ...
# 01/03/21        False          False       False        True       False  ...
#
#           Event_Unemployment Rate DEC  Event_Unemployment Rate FEB  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
#
#           Event_Unemployment Rate JAN  Event_Unemployment Rate JUL  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
#
#           Event_Unemployment Rate JUN  Event_Unemployment Rate MAR  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
#
#           Event_Unemployment Rate NOV  Event_Unemployment Rate OCT  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
#
#           Event_Unemployment Rate SEP  Event_Winter Economy Plan
# Date
# 01/01/19                        False                      False
# 01/01/20                        False                      False
# 01/02/23                        False                      False
# 01/03/20                        False                      False
# 01/03/21                        False                      False
#
# [5 rows x 493 columns]

# %% [markdown]
# We notice that some dates are duplicated (having more than one event) and some are missing (no events for that day).
#
# For the second issue, we do not need to address it now, as the missing dates will naturally appear as a result of the final merge.

# %%
callender_merged = callender_oneHotEncoded.groupby(callender_oneHotEncoded.index).any()
callender_merged
# Out:
#           Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  Day_Thursday  \
# Date
# 01/01/19       False       False         False       False         False
# 01/01/20       False       False         False       False         False
# 01/02/23       False        True         False       False         False
# 01/03/20        True       False         False       False         False
# 01/03/21       False       False         False        True         False
# ...              ...         ...           ...         ...           ...
# 12/23/22        True       False         False       False         False
# 12/30/19       False        True         False       False         False
# 12/30/20       False       False         False       False         False
# 12/30/21       False       False         False       False          True
# 12/30/22        True       False         False       False         False
#
#           Day_Tuesday  Day_Wednesday  Country_CA  Country_CN  Country_EA  ...  \
# Date                                                                      ...
# 01/01/19         True          False       False        True       False  ...
# 01/01/20        False           True       False        True       False  ...
# 01/02/23        False          False       False        True       False  ...
# 01/03/20        False          False       False       False       False  ...
# 01/03/21        False          False       False        True       False  ...
# ...               ...            ...         ...         ...         ...  ...
# 12/23/22        False          False       False       False       False  ...
# 12/30/19        False          False       False        True       False  ...
# 12/30/20        False           True       False        True       False  ...
# 12/30/21        False          False       False        True       False  ...
# 12/30/22        False          False       False        True       False  ...
#
#           Event_Unemployment Rate DEC  Event_Unemployment Rate FEB  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
# ...                               ...                          ...
# 12/23/22                        False                        False
# 12/30/19                        False                        False
# 12/30/20                        False                        False
# 12/30/21                        False                        False
# 12/30/22                        False                        False
#
#           Event_Unemployment Rate JAN  Event_Unemployment Rate JUL  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
# ...                               ...                          ...
# 12/23/22                        False                        False
# 12/30/19                        False                        False
# 12/30/20                        False                        False
# 12/30/21                        False                        False
# 12/30/22                        False                        False
#
#           Event_Unemployment Rate JUN  Event_Unemployment Rate MAR  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
# ...                               ...                          ...
# 12/23/22                        False                        False
# 12/30/19                        False                        False
# 12/30/20                        False                        False
# 12/30/21                        False                        False
# 12/30/22                        False                        False
#
#           Event_Unemployment Rate NOV  Event_Unemployment Rate OCT  \
# Date
# 01/01/19                        False                        False
# 01/01/20                        False                        False
# 01/02/23                        False                        False
# 01/03/20                        False                        False
# 01/03/21                        False                        False
# ...                               ...                          ...
# 12/23/22                        False                        False
# 12/30/19                        False                        False
# 12/30/20                        False                        False
# 12/30/21                        False                        False
# 12/30/22                        False                        False
#
#           Event_Unemployment Rate SEP  Event_Winter Economy Plan
# Date
# 01/01/19                        False                      False
# 01/01/20                        False                      False
# 01/02/23                        False                      False
# 01/03/20                        False                      False
# 01/03/21                        False                      False
# ...                               ...                        ...
# 12/23/22                        False                      False
# 12/30/19                        False                      False
# 12/30/20                        False                      False
# 12/30/21                        False                      False
# 12/30/22                        False                      False
#
# [888 rows x 493 columns]

# %%
callender_merged = callender_merged.astype(int)
callender_merged.head()
callender_merged.to_csv('../data/processed-data/economic_calendar_19_24.csv')

# %%
callender_merged.columns.to_numpy()
# Out:
# array(['Day_Friday', 'Day_Monday', 'Day_Saturday', 'Day_Sunday',
#        'Day_Thursday', 'Day_Tuesday', 'Day_Wednesday', 'Country_CA',
#        'Country_CN', 'Country_EA', 'Country_GB', 'Country_JP',
#        'Country_RU', 'Country_US',
#        'Event_20th National Congress of the Chinese Communist Party',
#        'Event_Autumn Budget', 'Event_Autumn Statement',
#        'Event_Balance of Trade\xa005', 'Event_Balance of Trade\xa0APR',
#        'Event_Balance of Trade\xa0AUG', 'Event_Balance of Trade\xa0DEC',
#        'Event_Balance of Trade\xa0FEB', 'Event_Balance of Trade\xa0JAN',
#        'Event_Balance of Trade\xa0JAN-FEB',
#        'Event_Balance of Trade\xa0JUL', 'Event_Balance of Trade\xa0JUN',
#        'Event_Balance of Trade\xa0MAR', 'Event_Balance of Trade\xa0NOV',
#        'Event_Balance of Trade\xa0OCT', 'Event_Balance of Trade\xa0SEP',
#        'Event_BoC Interest Rate Decision',
#        'Event_BoC Monetary Policy Report',
#        'Event_BoE Gov Bailey Speech\xa0',
#        'Event_BoE Interest Rate Decision', 'Event_BoE Pill Speech\xa0',
#        'Event_BoE Press Conference', 'Event_BoE Quantitative Easing',
#        'Event_BoJ Interest Rate Decision', 'Event_Brexit Deadline',
#        'Event_Building Permits Prel\xa005',
#        'Event_Building Permits Prel\xa0APR',
#        'Event_Building Permits Prel\xa0AUG',
#        'Event_Building Permits Prel\xa0DEC',
#        'Event_Building Permits Prel\xa0FEB',
#        'Event_Building Permits Prel\xa0JAN',
#        'Event_Building Permits Prel\xa0JUL',
#        'Event_Building Permits Prel\xa0JUN',
#        'Event_Building Permits Prel\xa0MAR',
#        'Event_Building Permits Prel\xa0NOV',
#        'Event_Building Permits Prel\xa0OCT',
#        'Event_Building Permits Prel\xa0SEP',
#        'Event_Building Permits\xa005', 'Event_Building Permits\xa0APR',
#        'Event_Building Permits\xa0AUG', 'Event_Building Permits\xa0DEC',
#        'Event_Building Permits\xa0FEB', 'Event_Building Permits\xa0JAN',
#        'Event_Building Permits\xa0JUL', 'Event_Building Permits\xa0JUN',
#        'Event_Building Permits\xa0MAR', 'Event_Building Permits\xa0NOV',
#        'Event_Building Permits\xa0OCT', 'Event_Building Permits\xa0SEP',
#        'Event_Business Confidence\xa005',
#        'Event_Business Confidence\xa0APR',
#        'Event_Business Confidence\xa0AUG',
#        'Event_Business Confidence\xa0DEC',
#        'Event_Business Confidence\xa0FEB',
#        'Event_Business Confidence\xa0JAN',
#        'Event_Business Confidence\xa0JUL',
#        'Event_Business Confidence\xa0JUN',
#        'Event_Business Confidence\xa0MAR',
#        'Event_Business Confidence\xa0NOV',
#        'Event_Business Confidence\xa0OCT',
#        'Event_Business Confidence\xa0SEP',
#        'Event_Caixin Manufacturing PMI\xa005',
#        'Event_Caixin Manufacturing PMI\xa0APR',
#        'Event_Caixin Manufacturing PMI\xa0AUG',
#        'Event_Caixin Manufacturing PMI\xa0DEC',
#        'Event_Caixin Manufacturing PMI\xa0FEB',
#        'Event_Caixin Manufacturing PMI\xa0JAN',
#        'Event_Caixin Manufacturing PMI\xa0JUL',
#        'Event_Caixin Manufacturing PMI\xa0JUN',
#        'Event_Caixin Manufacturing PMI\xa0MAR',
#        'Event_Caixin Manufacturing PMI\xa0NOV',
#        'Event_Caixin Manufacturing PMI\xa0OCT',
#        'Event_Caixin Manufacturing PMI\xa0SEP',
#        'Event_Chancellor Jeremy Hunt Statement',
#        'Event_Claimant Count Change\xa005',
#        'Event_Claimant Count Change\xa0APR',
#        'Event_Claimant Count Change\xa0AUG',
#        'Event_Claimant Count Change\xa0DEC',
#        'Event_Claimant Count Change\xa0FEB',
#        'Event_Claimant Count Change\xa0JAN',
#        'Event_Claimant Count Change\xa0JUL',
#        'Event_Claimant Count Change\xa0JUN',
#        'Event_Claimant Count Change\xa0MAR',
#        'Event_Claimant Count Change\xa0NOV',
#        'Event_Claimant Count Change\xa0OCT',
#        'Event_Claimant Count Change\xa0SEP',
#        'Event_Closed-door Fed Emergency Meeting',
#        'Event_Consumer Confidence\xa005',
#        'Event_Consumer Confidence\xa0APR',
#        'Event_Consumer Confidence\xa0AUG',
#        'Event_Consumer Confidence\xa0DEC',
#        'Event_Consumer Confidence\xa0FEB',
#        'Event_Consumer Confidence\xa0JAN',
#        'Event_Consumer Confidence\xa0JUL',
#        'Event_Consumer Confidence\xa0JUN',
#        'Event_Consumer Confidence\xa0MAR',
#        'Event_Consumer Confidence\xa0NOV',
#        'Event_Consumer Confidence\xa0OCT',
#        'Event_Consumer Confidence\xa0SEP',
#        'Event_Core Inflation Rate MoM\xa0AUG',
#        'Event_Core Inflation Rate MoM\xa0JUL',
#        'Event_Core Inflation Rate MoM\xa0JUN',
#        'Event_Core Inflation Rate MoM\xa0OCT',
#        'Event_Core Inflation Rate MoM\xa0SEP',
#        'Event_Core Inflation Rate YoY\xa005',
#        'Event_Core Inflation Rate YoY\xa0APR',
#        'Event_Core Inflation Rate YoY\xa0AUG',
#        'Event_Core Inflation Rate YoY\xa0DEC',
#        'Event_Core Inflation Rate YoY\xa0FEB',
#        'Event_Core Inflation Rate YoY\xa0JAN',
#        'Event_Core Inflation Rate YoY\xa0JUL',
#        'Event_Core Inflation Rate YoY\xa0JUN',
#        'Event_Core Inflation Rate YoY\xa0MAR',
#        'Event_Core Inflation Rate YoY\xa0NOV',
#        'Event_Core Inflation Rate YoY\xa0OCT',
#        'Event_Core Inflation Rate YoY\xa0SEP',
#        'Event_Core PCE Price Index MoM\xa005',
#        'Event_Core PCE Price Index MoM\xa0APR',
#        'Event_Core PCE Price Index MoM\xa0AUG',
#        'Event_Core PCE Price Index MoM\xa0DEC',
#        'Event_Core PCE Price Index MoM\xa0FEB',
#        'Event_Core PCE Price Index MoM\xa0JAN',
#        'Event_Core PCE Price Index MoM\xa0JUL',
#        'Event_Core PCE Price Index MoM\xa0JUN',
#        'Event_Core PCE Price Index MoM\xa0MAR',
#        'Event_Core PCE Price Index MoM\xa0OCT',
#        'Event_Core PCE Price Index MoM\xa0SEP',
#        'Event_Deposit Facility Rate',
#        'Event_Durable Goods Orders MoM\xa005',
#        'Event_Durable Goods Orders MoM\xa0APR',
#        'Event_Durable Goods Orders MoM\xa0AUG',
#        'Event_Durable Goods Orders MoM\xa0DEC',
#        'Event_Durable Goods Orders MoM\xa0FEB',
#        'Event_Durable Goods Orders MoM\xa0JAN',
#        'Event_Durable Goods Orders MoM\xa0JUL',
#        'Event_Durable Goods Orders MoM\xa0JUN',
#        'Event_Durable Goods Orders MoM\xa0MAR',
#        'Event_Durable Goods Orders MoM\xa0NOV',
#        'Event_Durable Goods Orders MoM\xa0OCT',
#        'Event_Durable Goods Orders MoM\xa0SEP',
#        'Event_ECB Forum on Central Banking',
#        'Event_ECB Interest Rate Decision',
#        'Event_ECB Macroeconomic Projections',
#        'Event_ECB President Lagarde Speech\xa0',
#        'Event_ECB Press Conference',
#        'Event_ECB Unscheduled Meeting to Discuss Markets',
#        'Event_Eurogroup Meeting', 'Event_Eurogroup Video Conference',
#        'Event_European Commission Spring Forecasts',
#        'Event_Exports YoY\xa0DEC', 'Event_Exports YoY\xa0NOV',
#        'Event_Exports YoY\xa0OCT', 'Event_Exports YoY\xa0SEP',
#        'Event_FOMC Minutes', 'Event_Fed Chair Powell Speech\xa0',
#        'Event_Fed Chair Powell Testimony',
#        'Event_Fed Interest Rate Decision', 'Event_Fed Press Conference',
#        'Event_Full Year GDP Growth\xa02019',
#        'Event_GDP Growth Annualized Prel\xa0Q1',
#        'Event_GDP Growth Annualized Prel\xa0Q2',
#        'Event_GDP Growth Annualized Prel\xa0Q3',
#        'Event_GDP Growth Annualized Prel\xa0Q4',
#        'Event_GDP Growth Rate QoQ 2nd Est\xa0Q2',
#        'Event_GDP Growth Rate QoQ 2nd Est\xa0Q3',
#        'Event_GDP Growth Rate QoQ Adv\xa0Q1',
#        'Event_GDP Growth Rate QoQ Adv\xa0Q2',
#        'Event_GDP Growth Rate QoQ Adv\xa0Q3',
#        'Event_GDP Growth Rate QoQ Adv\xa0Q4',
#        'Event_GDP Growth Rate QoQ Final\xa0Q2',
#        'Event_GDP Growth Rate QoQ Flash\xa0Q1',
#        'Event_GDP Growth Rate QoQ Flash\xa0Q2',
#        'Event_GDP Growth Rate QoQ Flash\xa0Q3',
#        'Event_GDP Growth Rate QoQ Flash\xa0Q4',
#        'Event_GDP Growth Rate QoQ Prel\xa0Q1',
#        'Event_GDP Growth Rate QoQ Prel\xa0Q2',
#        'Event_GDP Growth Rate QoQ Prel\xa0Q3',
#        'Event_GDP Growth Rate QoQ Prel\xa0Q4',
#        'Event_GDP Growth Rate QoQ\xa0Q1',
#        'Event_GDP Growth Rate QoQ\xa0Q2',
#        'Event_GDP Growth Rate QoQ\xa0Q3',
#        'Event_GDP Growth Rate QoQ\xa0Q4',
#        'Event_GDP Growth Rate YoY Flash\xa0Q1',
#        'Event_GDP Growth Rate YoY Flash\xa0Q2',
#        'Event_GDP Growth Rate YoY Flash\xa0Q3',
#        'Event_GDP Growth Rate YoY Flash\xa0Q4',
#        'Event_GDP Growth Rate YoY Prel\xa0Q1',
#        'Event_GDP Growth Rate YoY Prel\xa0Q2',
#        'Event_GDP Growth Rate YoY Prel\xa0Q3',
#        'Event_GDP Growth Rate YoY Prel\xa0Q4',
#        'Event_GDP Growth Rate YoY\xa0Q1',
#        'Event_GDP Growth Rate YoY\xa0Q2',
#        'Event_GDP Growth Rate YoY\xa0Q3',
#        'Event_GDP Growth Rate YoY\xa0Q4', 'Event_GDP MoM\xa005',
#        'Event_GDP MoM\xa0APR', 'Event_GDP MoM\xa0AUG',
#        'Event_GDP MoM\xa0DEC', 'Event_GDP MoM\xa0FEB',
#        'Event_GDP MoM\xa0JAN', 'Event_GDP MoM\xa0JUL',
#        'Event_GDP MoM\xa0JUN', 'Event_GDP MoM\xa0MAR',
#        'Event_GDP MoM\xa0NOV', 'Event_GDP MoM\xa0OCT',
#        'Event_GDP MoM\xa0SEP', 'Event_GDP YoY\xa0DEC',
#        'Event_GDP YoY\xa0OCT', 'Event_GfK Consumer Confidence\xa0DEC',
#        'Event_GfK Consumer Confidence\xa0NOV',
#        'Event_Gfk Consumer Confidence Final\xa005',
#        'Event_Gfk Consumer Confidence Final\xa0JUN',
#        'Event_Gfk Consumer Confidence\xa005',
#        'Event_Gfk Consumer Confidence\xa0APR',
#        'Event_Gfk Consumer Confidence\xa0AUG',
#        'Event_Gfk Consumer Confidence\xa0FEB',
#        'Event_Gfk Consumer Confidence\xa0JAN',
#        'Event_Gfk Consumer Confidence\xa0JUL',
#        'Event_Gfk Consumer Confidence\xa0JUN',
#        'Event_Gfk Consumer Confidence\xa0MAR',
#        'Event_Gfk Consumer Confidence\xa0OCT',
#        'Event_Gfk Consumer Confidence\xa0SEP',
#        'Event_ISM Manufacturing PMI\xa005',
#        'Event_ISM Manufacturing PMI\xa0APR',
#        'Event_ISM Manufacturing PMI\xa0AUG',
#        'Event_ISM Manufacturing PMI\xa0DEC',
#        'Event_ISM Manufacturing PMI\xa0FEB',
#        'Event_ISM Manufacturing PMI\xa0JAN',
#        'Event_ISM Manufacturing PMI\xa0JUL',
#        'Event_ISM Manufacturing PMI\xa0JUN',
#        'Event_ISM Manufacturing PMI\xa0MAR',
#        'Event_ISM Manufacturing PMI\xa0NOV',
#        'Event_ISM Manufacturing PMI\xa0OCT',
#        'Event_ISM Manufacturing PMI\xa0SEP',
#        'Event_ISM Non-Manufacturing PMI\xa005',
#        'Event_ISM Non-Manufacturing PMI\xa0APR',
#        'Event_ISM Non-Manufacturing PMI\xa0AUG',
#        'Event_ISM Non-Manufacturing PMI\xa0DEC',
#        'Event_ISM Non-Manufacturing PMI\xa0FEB',
#        'Event_ISM Non-Manufacturing PMI\xa0JAN',
#        'Event_ISM Non-Manufacturing PMI\xa0JUL',
#        'Event_ISM Non-Manufacturing PMI\xa0JUN',
#        'Event_ISM Non-Manufacturing PMI\xa0MAR',
#        'Event_ISM Non-Manufacturing PMI\xa0NOV',
#        'Event_ISM Non-Manufacturing PMI\xa0OCT',
#        'Event_ISM Non-Manufacturing PMI\xa0SEP',
#        'Event_ISM Services PMI\xa005', 'Event_ISM Services PMI\xa0APR',
#        'Event_ISM Services PMI\xa0AUG', 'Event_ISM Services PMI\xa0JUL',
#        'Event_ISM Services PMI\xa0JUN', 'Event_ISM Services PMI\xa0OCT',
#        'Event_ISM Services PMI\xa0SEP', 'Event_Imports YoY\xa0DEC',
#        'Event_Imports YoY\xa0NOV', 'Event_Imports YoY\xa0OCT',
#        'Event_Imports YoY\xa0SEP',
#        'Event_Industrial Production YoY\xa005',
#        'Event_Industrial Production YoY\xa0APR',
#        'Event_Industrial Production YoY\xa0AUG',
#        'Event_Industrial Production YoY\xa0DEC',
#        'Event_Industrial Production YoY\xa0JAN-FEB',
#        'Event_Industrial Production YoY\xa0JUL',
#        'Event_Industrial Production YoY\xa0JUN',
#        'Event_Industrial Production YoY\xa0MAR',
#        'Event_Industrial Production YoY\xa0NOV',
#        'Event_Industrial Production YoY\xa0OCT',
#        'Event_Industrial Production YoY\xa0SEP',
#        'Event_Inflation Rate MoM\xa005',
#        'Event_Inflation Rate MoM\xa0APR',
#        'Event_Inflation Rate MoM\xa0AUG',
#        'Event_Inflation Rate MoM\xa0JUL',
#        'Event_Inflation Rate MoM\xa0JUN',
#        'Event_Inflation Rate MoM\xa0MAR',
#        'Event_Inflation Rate MoM\xa0OCT',
#        'Event_Inflation Rate MoM\xa0SEP',
#        'Event_Inflation Rate YoY Flash\xa005',
#        'Event_Inflation Rate YoY Flash\xa0APR',
#        'Event_Inflation Rate YoY Flash\xa0AUG',
#        'Event_Inflation Rate YoY Flash\xa0DEC',
#        'Event_Inflation Rate YoY Flash\xa0FEB',
#        'Event_Inflation Rate YoY Flash\xa0JAN',
#        'Event_Inflation Rate YoY Flash\xa0JUL',
#        'Event_Inflation Rate YoY Flash\xa0JUN',
#        'Event_Inflation Rate YoY Flash\xa0MAR',
#        'Event_Inflation Rate YoY Flash\xa0NOV',
#        'Event_Inflation Rate YoY Flash\xa0OCT',
#        'Event_Inflation Rate YoY Flash\xa0SEP',
#        'Event_Inflation Rate YoY\xa005',
#        'Event_Inflation Rate YoY\xa0APR',
#        'Event_Inflation Rate YoY\xa0AUG',
#        'Event_Inflation Rate YoY\xa0DEC',
#        'Event_Inflation Rate YoY\xa0FEB',
#        'Event_Inflation Rate YoY\xa0JAN',
#        'Event_Inflation Rate YoY\xa0JUL',
#        'Event_Inflation Rate YoY\xa0JUN',
#        'Event_Inflation Rate YoY\xa0MAR',
#        'Event_Inflation Rate YoY\xa0NOV',
#        'Event_Inflation Rate YoY\xa0OCT',
#        'Event_Inflation Rate YoY\xa0SEP', 'Event_Ivey PMI s.a\xa005',
#        'Event_Ivey PMI s.a\xa0APR', 'Event_Ivey PMI s.a\xa0AUG',
#        'Event_Ivey PMI s.a\xa0DEC', 'Event_Ivey PMI s.a\xa0FEB',
#        'Event_Ivey PMI s.a\xa0JAN', 'Event_Ivey PMI s.a\xa0JUL',
#        'Event_Ivey PMI s.a\xa0JUN', 'Event_Ivey PMI s.a\xa0MAR',
#        'Event_Ivey PMI s.a\xa0NOV', 'Event_Ivey PMI s.a\xa0OCT',
#        'Event_Ivey PMI s.a\xa0SEP', 'Event_JOLTs Job Openings\xa005',
#        'Event_JOLTs Job Openings\xa0APR',
#        'Event_JOLTs Job Openings\xa0AUG',
#        'Event_JOLTs Job Openings\xa0DEC',
#        'Event_JOLTs Job Openings\xa0FEB',
#        'Event_JOLTs Job Openings\xa0JAN',
#        'Event_JOLTs Job Openings\xa0JUL',
#        'Event_JOLTs Job Openings\xa0JUN',
#        'Event_JOLTs Job Openings\xa0MAR',
#        'Event_JOLTs Job Openings\xa0NOV',
#        'Event_JOLTs Job Openings\xa0OCT',
#        'Event_JOLTs Job Openings\xa0SEP',
#        'Event_Jibun Bank Composite PMI Flash\xa0JAN',
#        'Event_Loan Prime Rate 1Y',
#        'Event_Markit Composite PMI Flash\xa0DEC',
#        'Event_Markit Composite PMI Flash\xa0JAN',
#        'Event_Markit Composite PMI Flash\xa0NOV',
#        'Event_Markit Composite PMI Flash\xa0OCT',
#        'Event_Markit Manufacturing PMI Flash\xa0DEC',
#        'Event_Markit Manufacturing PMI Flash\xa0NOV',
#        'Event_Markit Services PMI Flash\xa0DEC',
#        'Event_Markit Services PMI Flash\xa0NOV',
#        'Event_Markit/CIPS Composite PMI Flash\xa0DEC',
#        'Event_Markit/CIPS Composite PMI Flash\xa0JAN',
#        'Event_Markit/CIPS Composite PMI Flash\xa0NOV',
#        'Event_Markit/CIPS Composite PMI Flash\xa0OCT',
#        'Event_Markit/CIPS Manufacturing PMI Flash\xa0FEB',
#        'Event_Markit/CIPS Manufacturing PMI Flash\xa0MAR',
#        'Event_Markit/CIPS UK Services PMI Flash\xa0FEB',
#        'Event_Markit/CIPS UK Services PMI Flash\xa0MAR',
#        'Event_Michigan Consumer Sentiment Prel\xa005',
#        'Event_Michigan Consumer Sentiment Prel\xa0APR',
#        'Event_Michigan Consumer Sentiment Prel\xa0AUG',
#        'Event_Michigan Consumer Sentiment Prel\xa0DEC',
#        'Event_Michigan Consumer Sentiment Prel\xa0FEB',
#        'Event_Michigan Consumer Sentiment Prel\xa0JAN',
#        'Event_Michigan Consumer Sentiment Prel\xa0JUL',
#        'Event_Michigan Consumer Sentiment Prel\xa0JUN',
#        'Event_Michigan Consumer Sentiment Prel\xa0MAR',
#        'Event_Michigan Consumer Sentiment Prel\xa0NOV',
#        'Event_Michigan Consumer Sentiment Prel\xa0OCT',
#        'Event_Michigan Consumer Sentiment Prel\xa0SEP',
#        'Event_NBS Manufacturing PMI\xa005',
#        'Event_NBS Manufacturing PMI\xa0APR',
#        'Event_NBS Manufacturing PMI\xa0AUG',
#        'Event_NBS Manufacturing PMI\xa0DEC',
#        'Event_NBS Manufacturing PMI\xa0FEB',
#        'Event_NBS Manufacturing PMI\xa0JAN',
#        'Event_NBS Manufacturing PMI\xa0JUL',
#        'Event_NBS Manufacturing PMI\xa0JUN',
#        'Event_NBS Manufacturing PMI\xa0MAR',
#        'Event_NBS Manufacturing PMI\xa0NOV',
#        'Event_NBS Manufacturing PMI\xa0OCT',
#        'Event_NBS Manufacturing PMI\xa0SEP',
#        'Event_NPC Committee Meeting', "Event_National People's Congress",
#        'Event_National People’s Congress',
#        'Event_Non Farm Payrolls\xa005', 'Event_Non Farm Payrolls\xa0APR',
#        'Event_Non Farm Payrolls\xa0AUG', 'Event_Non Farm Payrolls\xa0DEC',
#        'Event_Non Farm Payrolls\xa0FEB', 'Event_Non Farm Payrolls\xa0JAN',
#        'Event_Non Farm Payrolls\xa0JUL', 'Event_Non Farm Payrolls\xa0JUN',
#        'Event_Non Farm Payrolls\xa0MAR', 'Event_Non Farm Payrolls\xa0NOV',
#        'Event_Non Farm Payrolls\xa0OCT', 'Event_Non Farm Payrolls\xa0SEP',
#        'Event_PM Liz Truss Speech\xa0', 'Event_PPI MoM\xa005',
#        'Event_PPI MoM\xa0APR', 'Event_PPI MoM\xa0AUG',
#        'Event_PPI MoM\xa0DEC', 'Event_PPI MoM\xa0FEB',
#        'Event_PPI MoM\xa0JAN', 'Event_PPI MoM\xa0JUL',
#        'Event_PPI MoM\xa0JUN', 'Event_PPI MoM\xa0MAR',
#        'Event_PPI MoM\xa0NOV', 'Event_PPI MoM\xa0OCT',
#        'Event_PPI MoM\xa0SEP',
#        'Event_Parliamentary Debate & Vote on Coronavirus Aid Package',
#        'Event_Personal Income MoM\xa005',
#        'Event_Personal Income MoM\xa0APR',
#        'Event_Personal Income MoM\xa0AUG',
#        'Event_Personal Income MoM\xa0DEC',
#        'Event_Personal Income MoM\xa0FEB',
#        'Event_Personal Income MoM\xa0JAN',
#        'Event_Personal Income MoM\xa0JUL',
#        'Event_Personal Income MoM\xa0JUN',
#        'Event_Personal Income MoM\xa0MAR',
#        'Event_Personal Income MoM\xa0NOV',
#        'Event_Personal Income MoM\xa0OCT',
#        'Event_Personal Income MoM\xa0SEP',
#        'Event_Personal Spending MoM\xa005',
#        'Event_Personal Spending MoM\xa0APR',
#        'Event_Personal Spending MoM\xa0AUG',
#        'Event_Personal Spending MoM\xa0DEC',
#        'Event_Personal Spending MoM\xa0FEB',
#        'Event_Personal Spending MoM\xa0JAN',
#        'Event_Personal Spending MoM\xa0JUL',
#        'Event_Personal Spending MoM\xa0JUN',
#        'Event_Personal Spending MoM\xa0MAR',
#        'Event_Personal Spending MoM\xa0NOV',
#        'Event_Personal Spending MoM\xa0OCT',
#        'Event_Personal Spending MoM\xa0SEP',
#        'Event_Premier Li Keqiang Speech\xa0',
#        'Event_President Biden Speech on Banking System\xa0',
#        'Event_President Biden Speech on Recovery Package\xa0',
#        'Event_President Biden and President Xi Jinping Virtual Meeting',
#        'Event_President Trump Speech\xa0',
#        'Event_President Trump Statement on Coronavirus',
#        'Event_Presidential Election',
#        'Event_Prime Minister Trudeau Speech\xa0',
#        'Event_Retail Sales MoM\xa005', 'Event_Retail Sales MoM\xa0APR',
#        'Event_Retail Sales MoM\xa0AUG', 'Event_Retail Sales MoM\xa0DEC',
#        'Event_Retail Sales MoM\xa0FEB', 'Event_Retail Sales MoM\xa0JAN',
#        'Event_Retail Sales MoM\xa0JUL', 'Event_Retail Sales MoM\xa0JUN',
#        'Event_Retail Sales MoM\xa0MAR', 'Event_Retail Sales MoM\xa0NOV',
#        'Event_Retail Sales MoM\xa0OCT', 'Event_Retail Sales MoM\xa0SEP',
#        'Event_Retail Sales YoY\xa0AUG', 'Event_Retail Sales YoY\xa0DEC',
#        'Event_Retail Sales YoY\xa0NOV', 'Event_Retail Sales YoY\xa0OCT',
#        'Event_Retail Sales YoY\xa0SEP',
#        'Event_S&P Global/CIPS Manufacturing PMI Flash\xa005',
#        'Event_S&P Global/CIPS Manufacturing PMI Flash\xa0APR',
#        'Event_S&P Global/CIPS Manufacturing PMI Flash\xa0AUG',
#        'Event_S&P Global/CIPS Manufacturing PMI Flash\xa0JUL',
#        'Event_S&P Global/CIPS Manufacturing PMI Flash\xa0JUN',
#        'Event_S&P Global/CIPS UK Services PMI Final\xa0AUG',
#        'Event_S&P Global/CIPS UK Services PMI Final\xa0JUL',
#        'Event_S&P Global/CIPS UK Services PMI Final\xa0JUN',
#        'Event_S&P Global/CIPS UK Services PMI Flash\xa005',
#        'Event_S&P Global/CIPS UK Services PMI Flash\xa0APR',
#        'Event_Spring Budget 2020', 'Event_Supplementary Budget',
#        'Event_Tankan Large Manufacturers Index\xa0Q1',
#        'Event_Tankan Large Manufacturers Index\xa0Q2',
#        'Event_Tankan Large Manufacturers Index\xa0Q3',
#        'Event_Tankan Large Manufacturers Index\xa0Q4',
#        'Event_Treasury Secretary Yellen Senate Confirmation Hearing',
#        'Event_UK Autumn Statement',
#        'Event_US-China Phase 1 Trade Deal Signature',
#        'Event_US-China Trade Talks', 'Event_USMCA Trade Deal Signature',
#        'Event_Unemployment Rate - Adjusted\xa0AUG',
#        'Event_Unemployment Rate\xa005', 'Event_Unemployment Rate\xa0APR',
#        'Event_Unemployment Rate\xa0AUG', 'Event_Unemployment Rate\xa0DEC',
#        'Event_Unemployment Rate\xa0FEB', 'Event_Unemployment Rate\xa0JAN',
#        'Event_Unemployment Rate\xa0JUL', 'Event_Unemployment Rate\xa0JUN',
#        'Event_Unemployment Rate\xa0MAR', 'Event_Unemployment Rate\xa0NOV',
#        'Event_Unemployment Rate\xa0OCT', 'Event_Unemployment Rate\xa0SEP',
#        'Event_Winter Economy Plan'], dtype=object)

# %% [markdown]
# Note: This is not the final dataset for model training. We will **reduce** it further.
#
# Possible ways to reduce the number of columns:
# - Group similar events into broader categories.
# - Remove events that occur very infrequently.
# - Analyze the impact of frequent events and merge those with similar effects.
# - Drop columns with low variance (e.g., columns with mostly zeros).
# - Use dimensionality reduction techniques like PCA to combine correlated columns.
# - we might get rid of the weekend during the merging since we can trade on weekends
