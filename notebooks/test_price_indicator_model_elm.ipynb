# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %%
try:
    layer = tf.keras.layers.LSTM(units=50, return_sequences=True)
    print("tf.keras.models!")
except AttributeError as e:
    print(f"Error: {e}")
# Out:
# tf.keras.models!

# %%
price_gold = pd.read_csv('https://raw.githubusercontent.com/elm19/GoldSpot-Predictor/refs/heads/main/data/processed-data/meged_data_price_indicator.csv', index_col='Date')
print(price_gold.head())

lookback_period = 10
test_size = 0.2

data = price_gold[['Open', 'Close', 'High', 'Low', 'Vol.']].copy()
data = data.dropna()  # Handle potential missing values

# Scale the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)
# Out:
#              Close    Open    High     Low      Vol. Change %  FEDFUNDS  \
# Date
# 2019-01-01  1281.3  1283.0  1286.5  1279.7  113260.0   -0.13%       2.4
# 2019-01-02  1284.1  1285.0  1291.0  1280.6  235330.0    0.22%       2.4
# 2019-01-03  1294.8  1288.5  1296.9  1286.4  244540.0    0.83%       2.4
# 2019-01-04  1285.8  1296.5  1300.4  1278.1  316060.0   -0.70%       2.4
# 2019-01-05  1285.8  1296.5  1300.4  1278.1  316060.0   -0.70%       2.4
#
#             CPIAUCSL  DFII10  UNRATE   Close_DX    High_DX     Low_DX  \
# Date
# 2019-01-01   252.561    0.97     4.0  96.494999  96.735001  95.945000
# 2019-01-02   252.561    0.96     4.0  96.820000  96.959999  95.820000
# 2019-01-03   252.561    0.88     4.0  96.309998  96.750000  96.209999
# 2019-01-04   252.561    0.91     4.0  96.190002  96.610001  96.050003
# 2019-01-05   252.561    0.91     4.0  96.190002  96.610001  96.050003
#
#               Open_DX  Volume_DX
# Date
# 2019-01-01  96.270000        0.0
# 2019-01-02  96.139999        0.0
# 2019-01-03  96.720001        0.0
# 2019-01-04  96.279999        0.0
# 2019-01-05  96.279999        0.0

# %%
price_gold.shape
# Out:
# (1796, 15)

# %%
import numpy as np

def create_sequences(data, lookback):
    X, y = [], []
    for i in range(lookback, len(data) - 6):
        X.append(data[i - lookback:i])
        y.append(data[i:i + 6, 1])                    # Prédiction : 6 prochaines valeurs de la colonne 1 (ex : 'Close')
    return np.array(X), np.array(y)


X, y = create_sequences(scaled_data, lookback_period)

# Split into training and testing sets
train_size = int(len(X) * (1 - test_size))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (1424, 10, 5)
# Shape of X_test: (356, 10, 5)
# Shape of y_train: (1424, 6)
# Shape of y_test: (356, 6)

# %%
import tensorflow as tf

# Création du modèle LSTM
model_LSTM = tf.keras.models.Sequential()
model_LSTM.add(tf.keras.layers.LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_LSTM.add(tf.keras.layers.LSTM(units=50))
model_LSTM.add(tf.keras.layers.Dense(units=6))

model_LSTM.compile(optimizer='adam', loss='mean_squared_error')

history_LSTM = model_LSTM.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.1365
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0027
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0022
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0023
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0021
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0021
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0020
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0021
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0021
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0014
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0014
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0016
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0015
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0014

# %%
model_LSTM.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_23 (LSTM)                       │ (None, 10, 50)              │          11,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_24 (LSTM)                       │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 6)                   │             306 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 95,120 (371.57 KB)
#  Trainable params: 31,706 (123.85 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 63,414 (247.71 KB)

# %% [markdown]
# Plot de  loss

# %%
plt.plot(history_LSTM.history['loss'], label='Loss entraînement')
plt.xlabel('Épochs')
plt.ylabel('Loss')
plt.title('Courbe de Loss pour LSTM')
plt.legend()
plt.grid(True)
plt.show()

# %%
LSTM_MSE = model_LSTM.evaluate(X_test, y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0021

# %%
predicted_scaled = model_LSTM.predict(X_test)

# Inverse transform the predictions
predicted_prices = np.zeros((predicted_scaled.shape[0], predicted_scaled.shape[1]))
for i in range(predicted_scaled.shape[1]):
    dummy_predictions = np.zeros((len(predicted_scaled), 5))
    dummy_predictions[:, 1] = predicted_scaled[:, i]
    predicted_prices[:, i] = scaler.inverse_transform(dummy_predictions)[:, 1]

# Get the actual 'Close' prices from the test set
test_start_index = int(len(data) * (1 - test_size))+lookback_period
actual_close_test = data['Close'].iloc[test_start_index:]
num_test_samples = predicted_prices.shape[0]
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step

# %%
reel_prices = [y_test[i, 0] for i in range(y_test.shape[0])]
reel_prices = np.array(reel_prices)
plt.plot(reel_prices)
plt.plot([predicted_scaled[i, 0] for i in range(len(predicted_scaled)) ])
plt.title('Reel Close Prices')
plt.xlabel('Time Step')
plt.ylabel('Close Price')
plt.grid(True)

plt.show()

# %% [markdown]
# RNN

# %%
model_RNN = tf.keras.models.Sequential()
model_RNN.add(tf.keras.layers.SimpleRNN(units=50,activation = "tanh", return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_RNN.add(tf.keras.layers.SimpleRNN(units=50))
model_RNN.add(tf.keras.layers.Dense(units=6))  # Output layer to predict the next 'Close' price

# 3. Compile the model
Adam=tf.keras.optimizers.Adam(learning_rate=0.04)
model_RNN.compile(optimizer='adam', loss='mean_squared_error')

model_RNN.compile(optimizer = Adam,
                  loss = "mean_squared_error",
                  metrics=['mae'])

# 4. Train the model
history_RNN= model_RNN.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)



model_RNN.summary()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.7173 - mae: 0.6102
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0689 - mae: 0.2124
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0633 - mae: 0.2054
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0567 - mae: 0.1909
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0431 - mae: 0.1596
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0479
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0070 - mae: 0.0679
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0040 - mae: 0.0504
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0021 - mae: 0.0358
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0426
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - mae: 0.0404
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - mae: 0.0464
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mae: 0.0661
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0072 - mae: 0.0682
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0050 - mae: 0.0543
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0541
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0523
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057 - mae: 0.0597
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0087 - mae: 0.0766
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0036 - mae: 0.0474
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mae: 0.0722
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054 - mae: 0.0568
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0035 - mae: 0.0465
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0062 - mae: 0.0642
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0035 - mae: 0.0457
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0596 - mae: 0.1845
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1515 - mae: 0.3183
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0976 - mae: 0.2517
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1322 - mae: 0.2985
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1229 - mae: 0.2868
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0641 - mae: 0.2065
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0825 - mae: 0.2333
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0809 - mae: 0.2308
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0677 - mae: 0.2112
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1017 - mae: 0.2545
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0669 - mae: 0.2124
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0638 - mae: 0.2072
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0835 - mae: 0.2342
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0765 - mae: 0.2237
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0876 - mae: 0.2408
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0636 - mae: 0.2077
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0960 - mae: 0.2532
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0736 - mae: 0.2217
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0735 - mae: 0.2231
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0765 - mae: 0.2218
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0797 - mae: 0.2320
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0747 - mae: 0.2258
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0822 - mae: 0.2305
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0719 - mae: 0.2183
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0834 - mae: 0.2356
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_6 (SimpleRNN)             │ (None, 10, 50)              │           2,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_7 (SimpleRNN)             │ (None, 50)                  │           5,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 6)                   │             306 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,470 (95.59 KB)
#  Trainable params: 8,156 (31.86 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 16,314 (63.73 KB)

# %%
plt.plot(history_RNN.history['loss'], label='Loss entraînement')
plt.xlabel('Épochs')
plt.ylabel('Loss')
plt.title('Courbe de Loss pour RNN')
plt.legend()
plt.grid(True)
plt.show()

# %%
RNN_MSE = model_RNN.evaluate(X_test, y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0652 - mae: 0.2390

# %%
y_predicted_scaled_RNN=model_RNN.predict(X_test)

# Inverse transform the predictions
y_predicted_scaled_RNN = np.zeros((predicted_scaled.shape[0], predicted_scaled.shape[1]))
for i in range(predicted_scaled.shape[1]):
    dummy_predictions = np.zeros((len(predicted_scaled), 5))
    dummy_predictions[:, 1] = predicted_scaled[:, i]
    y_predicted_scaled_RNN[:, i] = scaler.inverse_transform(dummy_predictions)[:, 1]

# Get the actual 'Close' prices from the test set
test_start_index = int(len(data) * (1 - test_size))+lookback_period
actual_close_test = data['Close'].iloc[test_start_index:]
num_test_samples = y_predicted_scaled_RNN.shape[0]
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
reel_prices = [y_test[i, 0] for i in range(y_test.shape[0])]
reel_prices = np.array(reel_prices)
plt.plot(reel_prices)
plt.plot([predicted_scaled[i, 0] for i in range(len(predicted_scaled)) ])
plt.title('Reel Close Prices')
plt.xlabel('Time Step')
plt.ylabel('Close Price')
plt.grid(True)

plt.show()

# %% [markdown]
# GRU

# %%
model_GRU = tf.keras.models.Sequential()
model_GRU.add(tf.keras.layers.GRU(units=50,activation = "tanh", return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_GRU.add(tf.keras.layers.GRU(units=32))
model_GRU.add(tf.keras.layers.Dense(units=6))  # Output layer to predict the next 'Close' price

# 3. Compile the model
Adam=tf.keras.optimizers.Adam(learning_rate=0.04)
model_GRU.compile(optimizer='adam', loss='mean_squared_error')

model_GRU.compile(optimizer = Adam,
                  loss = "mean_squared_error",
                  metrics=['mae'])

# 4. Train the model

history_GRU= model_GRU.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

model_GRU.summary()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1251 - mae: 0.2257
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0023 - mae: 0.0361
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0024 - mae: 0.0386
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0018 - mae: 0.0329
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - mae: 0.0317
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0016 - mae: 0.0295
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014 - mae: 0.0276
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mae: 0.0246
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017 - mae: 0.0309
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - mae: 0.0296
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0016 - mae: 0.0300
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mae: 0.0245
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mae: 0.0280
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - mae: 0.0270
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0255
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mae: 0.0255
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - mae: 0.0277
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mae: 0.0252
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0012 - mae: 0.0253
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - mae: 0.0297
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mae: 0.0274
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0255
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - mae: 0.0291
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mae: 0.0268
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0250
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0016 - mae: 0.0302
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0015 - mae: 0.0288
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - mae: 0.0255
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0255
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - mae: 0.0250
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0014 - mae: 0.0282
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014 - mae: 0.0279
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011 - mae: 0.0254
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mae: 0.0259
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - mae: 0.0316
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0257
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mae: 0.0256
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - mae: 0.0250
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mae: 0.0269
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mae: 0.0278
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - mae: 0.0247
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - mae: 0.0243
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0262
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mae: 0.0280
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0013 - mae: 0.0270
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0011 - mae: 0.0248
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0257
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0241
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mae: 0.0268
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - mae: 0.0278
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru_6 (GRU)                          │ (None, 10, 50)              │           8,550 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_7 (GRU)                          │ (None, 32)                  │           8,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 6)                   │             198 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,438 (197.03 KB)
#  Trainable params: 16,812 (65.67 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 33,626 (131.36 KB)

# %%
plt.plot(history_GRU.history['loss'], label='Loss entraînement')
plt.xlabel('Épochs')
plt.ylabel('Loss')
plt.title('Courbe de Loss pour GRU')
plt.legend()
plt.grid(True)
plt.show()

# %%
GRU_MSE = model_GRU.evaluate(X_test, y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0016 - mae: 0.0326

# %%
y_predicted_scaled_GRU = model_GRU.predict(X_test)

# Inverse transform the predictions
y_predicted_scaled_GRU = np.zeros((predicted_scaled.shape[0], predicted_scaled.shape[1]))
for i in range(predicted_scaled.shape[1]):
    dummy_predictions = np.zeros((len(predicted_scaled), 5))
    dummy_predictions[:, 1] = predicted_scaled[:, i]
    y_predicted_scaled_GRU[:, i] = scaler.inverse_transform(dummy_predictions)[:, 1]

# Get the actual 'Close' prices from the test set
test_start_index = int(len(data) * (1 - test_size))+lookback_period
actual_close_test = data['Close'].iloc[test_start_index:]
num_test_samples = y_predicted_scaled_GRU.shape[0]
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step

# %%
reel_prices = [y_test[i, 0] for i in range(y_test.shape[0])]
reel_prices = np.array(reel_prices)
plt.plot(reel_prices)
plt.plot([predicted_scaled[i, 0] for i in range(len(predicted_scaled)) ])
plt.title('Reel Close Prices')
plt.xlabel('Time Step')
plt.ylabel('Close Price')
plt.grid(True)

plt.show()

# %%
from tensorflow.keras.callbacks import TensorBoard
import datetime

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

model_GRU.fit(X_train, y_train, epochs=50,
          callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mae: 0.0259
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mae: 0.0258
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0237
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0244
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0011 - mae: 0.0249
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - mae: 0.0277
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0010 - mae: 0.0237
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0254
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0271
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0260
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0243
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0240
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0254
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0248
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0274
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0011 - mae: 0.0256
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0013 - mae: 0.0282
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0234
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0280
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0248
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0240
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mae: 0.0289
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - mae: 0.0240
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0248
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0261
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - mae: 0.0263
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.8427e-04 - mae: 0.0238
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mae: 0.0294
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 8.4745e-04 - mae: 0.0220
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.7024e-04 - mae: 0.0219
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.1792e-04 - mae: 0.0230
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.7743e-04 - mae: 0.0221
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1385e-04 - mae: 0.0226
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0246
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0239
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1822e-04 - mae: 0.0224
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0265
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6755e-04 - mae: 0.0237
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.9771e-04 - mae: 0.0235
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mae: 0.0297
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 9.9096e-04 - mae: 0.0237
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.9777e-04 - mae: 0.0227
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - mae: 0.0255
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mae: 0.0278
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0236
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0242
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0010 - mae: 0.0242
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9058e-04 - mae: 0.0227
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9685e-04 - mae: 0.0228
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.9796e-04 - mae: 0.0241

# %% [markdown]
# for collab

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit

# %% [markdown]
# for terminal

# %%
# !tensorboard --logdir=logs/fit

# %%
print("LSTM MSE:", LSTM_MSE)
print("RNN MSE:", RNN_MSE)
print("GRU MSE:", GRU_MSE)
# Out:
# LSTM MSE: 0.002388804452493787
# RNN MSE: [0.07989399880170822, 0.2715173661708832]
# GRU MSE: [0.0018474997486919165, 0.0347021259367466]
